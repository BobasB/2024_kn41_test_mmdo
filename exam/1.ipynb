# %% [markdown]
# ## Завдання
# 1. У роботі №3, файл swords.py, протестувати/написати тест для проперті `def rarity_type`
#
# - оскільки завдання у роботі №3 то там створюємо файл або модифікуємо файл згідно завдання, в нашому випадку створили у роботі №3 файл `test_exam.py`
# - написали код у цьому файлі, та виконали тестування проперті `def rarity_type`
# - запускаємо код та виводимо результати
# - код працюючий, результат представлений на скріншоті
# > ![](./exam_result.jpg)
#
# 2. У роботі №1, у проекті 4_project дописати нову веб сторінку з назвою info яка буде виводити повідомлення що ви зробили екзамен
#
# - заходимо по шляху згідно завдання, 1_lab/4_project, бачимо що там є програма на flask яка робити веб сайт
# - нам потрібно зробити нову веб сторінку, доробляємо її, пишемо код
# - перевіряємо працездатність коду запускаючи його
# - результат виконання завдання представлений на скріншоті
# > ![](./exam_consult.jpg)

# %% [markdown]
# ## Завдання на екзамен 16 квітня

# %% [markdown]
# 1. (__Роман Лесик__) У роботі №1, модифікувати проект 1_project, за допомогою бібліотеки requests зайти на сторінку https://itcollege.lviv.ua/ та вивести її вміст
#
# 2. (__Дмитро Гаваньо__) У роботі №3, для файлу game/buff.py написати тест до методу berserk
#
# 3. (__Анастасія Крижанівська__) У роботі №1, у проекті 2_project інсталювати бібліотеку matplotlib та виконати приклад з https://matplotlib.org/stable/users/getting_started/
#
# 4. (__Іванна Шумлянська__) У роботі №2, для файлу game/swords.py протестувати функцію attack з класу SwordsSecond (написати юніт тест)
#
# 5. (__Назарій Захарчук__) У роботі №2, для файлу game/buff.py створити новий бонус меча у класу Buff який буде збільшувати damage на 5 та зменшувати vitality на 1
#
# 6. (__Марко Мисак__) У роботі №1, у проекті 3_project, задати змінну середовища під назвою EXAM та вивести її при виконання програми 3.py
#
# 7. (__Микола Логойда__) У роботі №2, для файлу game/buff.py модифікувати метод poisoning щоб отрута тепер наносила шкоду мечу і забирала 2 vitality
#
# 8. (__Олег Боршовський__) У роботі №3, встановити у віртуальне середовище Pipenv бібліотеку requests та у файлі app.py написати метод який буде заходити на сайт https://itcollege.lviv.ua/
#
# 9. (__Максим Шніцар__) У роботі №2, для файлу game/swords.py протестувати функцію expire_buff з класу SwordsSecond (написати юніт тест)
#
# 10. (__Арсен Дерпак__) У роботі №1, у проекті 4_project, встановити у віртуальне середовище Pipenv бібліотеку requests та викликати метод requests.get коли викликається головна сторінка index з файлу app.py
#
# 11. (__Анна Ханик__) У роботі №3, у файлі test.py модифікувати тест test_create_sword_for_player з класу TestGame щоб створювалось декілька мечів у циклі для різних гравців та перевірялись їх відповідність
#
# 12. (__Денис Гаврилюк__) У роботі №2, для файлу game/buff.py протестувати функцію crystals з класу Buff (написати юніт тест)
#
# 13. (__Сергій Циганський__) У роботі №3, у файлі app.py модифікувати функцію get_player_name та зробіть перевірку щоб Імя гравця складалось хочаб з декількох букв
#
# 14. (__Назарій Тришкура__) У роботі №2, для файлу game/swords.py модифікувати конструктор класу SwordsSecond та задати значення імені меча name по замовчуванню як Простий Меч
#
# 15. У роботі №3, у файлі test.py дописати тест у класі TestSwords який тестує створення меча згідно основного конструктора класу SwordsSecond
#
# 16. (__Олександр Михайляк__) У роботі №3, у файлі test.py модифікувати тест test_constants та зробити перевірку з неіснуючим іменем Меча
#
# 17. (__Богдан Савін__) У роботі №2, для файлу game/swords.py дописати property для класу SwordsSecond яка буде виводити стрічку та вказувати яка загільна кількість мечів вже буда створена
#
# 18. У роботі №1, у проекті 4_project, створити файл .env та додати змінну середовища HELP, та прочитати її коли заходите на веб сторінку /help

# %% [markdown]
# ## Проведення екзамену, 16 квітня 2024р.

# %% [markdown]
# "+" Здані роботи
# "*" повідомили
# "^" прийшов на екзамен
#
# |№|Студент|Примітка|Оцінка|
# |---|---|---|---|
# |1. | Олег Боршовський      |^||
# |2. | Дмитро Гаваньо        |^+|5|
# |3. | Денис Гаврилюк        |^*|3|
# |4. | Арсен Дерпак          |   ^+||
# |5. | Назарій Захарчук      |^+*|4|
# |6. | Анастасія Крижанівська|^+|4|
# |7. | Роман Лесик           |^|3|
# |8. | Микола Логойда        |   ^||
# |9. | Марко Мисак           |^||
# |10.| Олександр Михайляк    |^*||
# |11.| Богдан Савін          |^*||
# |12.| Назарій Тришкура      |^*||
# |13.| Анна Ханик            |^*|4|
# |14.| Сергій Циганський     |^*||
# |15.| Максим Шніцар         |^+*||
# |16.| Іванна Шумлянська     |^+|5|
